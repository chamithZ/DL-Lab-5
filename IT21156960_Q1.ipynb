# %% [markdown]
# <a href="https://colab.research.google.com/github/chamithZ/DL-Lab-5/blob/main/IT21156960_Q1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
def generate_sine_wave(seq_length=100, num_samples=1000):
    x = np.linspace(0, 50, num_samples)
    y = np.sin(x)
    return y

# %%
def generate_dataset(data, time_step=10):
    X, y = [], []
    for i in range(len(data) - time_step - 1):
        X.append(data[i:(i + time_step)])
        y.append(data[i + time_step])
    return np.array(X), np.array(y)

# %%
data = generate_sine_wave()
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data.reshape(-1, 1)).reshape(-1)

# %%
# Create the Dataset
time_step = 10  # Time steps for RNN input
X, y = generate_dataset(data, time_step)

# %%
# Reshape for RNN input [samples, time steps, features]
X = X.reshape(X.shape[0], X.shape[1], 1)

# %%
model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1)  # <-- Experiment with 'epochs' and 'batch_size'
# Out:
# Epoch 1/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1942e-05
# Epoch 2/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4583e-05
# Epoch 3/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1170e-05
# Epoch 4/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9610e-05
# Epoch 5/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9196e-05
# Epoch 6/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0841e-05
# Epoch 7/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9378e-05
# Epoch 8/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7080e-05
# Epoch 9/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6831e-05
# Epoch 10/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6124e-05
# Epoch 11/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8462e-05
# Epoch 12/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4449e-05
# Epoch 13/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4679e-05
# Epoch 14/50
# ...

# %%
y_pred = model.predict(X_test)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
# 6. Plot the Results
plt.figure(figsize=(12, 6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.xlabel('Time Steps')
plt.ylabel('Value')
plt.title('RNN Prediction on Sine Wave')
plt.legend()
plt.show()

# %% [markdown]
# **Modify the Units Parameter in the SimpleRNN Layer**
#
#  Increasing the number of hidden units generally enhances the model's ability to capture complex patterns in the sequence, leading to better predictions. However, too many units might cause overfitting, where the model performs well on training data but poorly on unseen data.
#
# **Adjust the Epochs and Batch Size**
#
#  More epochs usually allow the model to learn better, but too many epochs might lead to overfitting. Adjusting batch size affects how quickly the model learns; a smaller batch size may lead to a noisier gradient update, potentially resulting in better generalization.
#
# **Analyze the Resulting Plot**
# If the predicted values deviate significantly,  Need to reduce the learning rate or increase the number of hidden units. It's also essential to ensure that the model is not underfitting (too few units or epochs) or overfitting (too many units or epochs).
